# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
mean1=np.array([1,0])
cov1=([[10,0.1],[0.1,10]])
dist1=np.random.multivariate_normal(mean1,cov1,500)

mean2=np.array([4,5])
cov2=([[10,0.1],[0.1,10]])
dist2=np.random.multivariate_normal(mean2,cov2,500)

plt.scatter(dist1[:,0],dist1[:,1])
plt.scatter(dist2[:,0],dist2[:,1])
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show()

# %%
data= np.zeros((1000, 3))
data[:500,:2]=dist1
data[500:,:2]=dist2
data[500:,-1]=1
data.mean(axis=0)#axis=0 column wise
# Out:
# array([2.52989505, 2.35165985, 0.5       ])

# %%
def distance(a,b):
    return (np.sum((a-b)**2))**0.5

# %%
def KNN(x_train,y_train,test_point,k=7):
    m=x_train.shape[0]#(1000,2)
    vals=[]
    for i in range(m):
        d=distance(x_train[i],test_point)
        vals.append([d,y_train[i]])
    sorted_val=sorted(vals,key=lambda r:r[0])
    neighbours=np.asarray(sorted_val)[:k,-1]#(7,)
    freq=np.unique(neighbours,return_counts=True)
    index=freq[1].argmax()
    return freq[0][index]

# %%
def acc(k):
    predictions=[]
    for i in range(x_test.shape[0]):
        test_point=x_test[i]
        predicted=KNN(x_train,y_train,test_point,k)
        predictions.append(predicted)
   # print(predictions==y_test)
    matches=(np.array(predictions)==y_test).sum()
    return((matches*100)/x_test.shape[0])

# %%
#1
l1=[]
for k in range(1,51):
    #print(f"For k={k} Accuuracy={acc(k)}")
    l1[k]=acc(k)
print(l1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-79081c2ee7a6> in <module>()
#       3 for k in range(1,51):
#       4     #print(f"For k={k} Accuuracy={acc(k)}")
# ----> 5     l1[k]=acc(k)
#       6 print(l1)
#
# <ipython-input-6-11e376013376> in acc(k)
#       1 def acc(k):
#       2     predictions=[]
# ----> 3     for i in range(x_test.shape[0]):
#       4         test_point=x_test[i]
#       5         predicted=KNN(x_train,y_train,test_point,k)
#
# NameError: name 'x_test' is not defined

# %%
from platform import python_version
print(python_version())
# Out:
# 3.7.0
